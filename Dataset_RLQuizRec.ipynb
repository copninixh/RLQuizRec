# %% [markdown]
# <a href="https://colab.research.google.com/github/copninixh/RLQuizRec/blob/main/Dataset_RLQuizRec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U datasets huggingface_hub fsspec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.3/489.3 kB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 13.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.31.2
#     Uninstalling huggingface-hub-0.31.2:
#       Successfully uninstalled huggingface-hub-0.31.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import pandas as pd
from datasets import load_dataset

# %%
a_level = load_dataset("scb10x/thai_exam", "a_level")
a_level
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'a', 'b', 'c', 'd', 'e', 'answer', 'subject'],
#         num_rows: 5
#     })
#     test: Dataset({
#         features: ['question', 'a', 'b', 'c', 'd', 'e', 'answer', 'subject'],
#         num_rows: 127
#     })
# })

# %%
splits = {'train': 'data/onet/onet_train.jsonl', 'test': 'data/onet/onet_test.jsonl'}
df = pd.read_json("hf://datasets/scb10x/thai_exam/" + splits["test"], lines=True)
df
# Out:
#      year    no                                           question  \
# 0    2021   1.2  เวลาเช้าตรู่ที่อากาศเย็นเรามักสังเกตเห็นหยดน้ำ...
# 1    2021   2.1  ใช้ข้อความต่อไปนี้ตอบคำถามข้อ ก และ ข้อ ข\nการ...
# 2    2021   2.2  ใช้ข้อความต่อไปนี้ตอบคำถามข้อ ก และ ข้อ ข\nการ...
# 3    2021   3.2  ใช้ข้อความต่อไปนี้ตอบคำถามข้อ ก และข้อ ข\nกรรม...
# 4    2021   4.1  ใช้ข้อความต่อไปนี้ตอบคำถามข้อ ก และ ข้อ ข\n๑) ...
# ..    ...   ...                                                ...
# 157  2021  52.0  คำประพันธ์ต่อไปนี้กล่าวถึงเรื่องใดเป็นสำคัญ\nน...
# 158  2021   1.1  เวลาเช้าตรู่ที่อากาศเย็นเรามักสังเกตเห็นหยดน้ำ...
# 159  2021  53.0  คำประพันธ์ต่อไปนี้นำเสนอความคิดเรื่องใดเป็นสำค...
# 160  2021  28.0  ข้อใดเรียงลำดับข้อความต่อไปนี้ได้ถูกต้อง \n๑ ก...
# 161  2021   7.0  ข้อใดไม่สอดคล้องกับข้อความต่อไปนี้\nวิตามินดีช...
#
#                                                      a  \
# 0                                                ๑ คํา
# ...
